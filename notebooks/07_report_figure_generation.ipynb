# %% [markdown]
# # Report Figure Generation

# %% [markdown]
# # Report Figure Generation
#
# ## Goal
# Create final clean tables and figures for the report and presentation.
#
# ## Required outputs
# - publication-ready figures
# - stable filenames
# - captions draft
# - export list for report/slides

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
PROJECT_ROOT
